# %% [markdown]
# # Autoencoder (AE) Implementation with Nature-Inspired Optimization
# ### MSC/DSA/134
#
# This notebook implements an Autoencoder for fraud detection.
# Optimization Goal: Find the best architecture (Encoder Layers, Decoder Layers, Latent Size, Units, Dropout) that maximizes the F1 score (Anomaly Detection performance).

# %%
from globals.pandas_functions import *
import globals.hyperparameter_optimizer as hyp_optimizer
import globals.torch_gpu_processing as torch_gpu_processing
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# import datasets
data_base_path = "data/processed/null_value_option_1_with_validation_set/scaled_only"

X_train = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_x_train_scaled.csv")
X_validation = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_x_validation_scaled.csv")
X_test = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_x_test_scaled.csv")

y_train = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_y_train.csv")
y_validation = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_y_validation.csv")
y_test = pd.read_csv(f"{data_base_path}/unified_transaction_data_option2_y_test.csv")

print("X_train:", X_train.shape)
print("X_validation:", X_validation.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (354305, 26)
# X_validation: (118102, 26)
# X_test: (118102, 26)

# %%
torch_gpu_processing.test_direct_ml_processing()
# Out:
# torch: 2.4.1+cpu
# DirectML device: privateuseone:0
# Tensor device: privateuseone:0

# %%
# get a sample for optimization
sample_size = 25000
seed = 42

def get_stratified_sample(X, y, sample_size, random_state=42):
    if sample_size >= len(X): return X, y
    X_sample, _, y_sample, _ = train_test_split(
        X, y, train_size=sample_size, stratify=y, random_state=random_state
    )
    return X_sample, y_sample

X_train_sample, y_train_sample = get_stratified_sample(
    X_train.to_numpy(),
    y_train.to_numpy().ravel(),
    sample_size=sample_size,
    random_state=seed
)

print(f"Optimization Sample Size: {len(X_train_sample)}")
# Out:
# Optimization Sample Size: 25000

# %%
# ==========================================
# HYPERPARAMETER OPTIMIZATION (AE)
# ==========================================

# Settings
param_optimizer_algorithm = "FA" # (FA, GWO, etc)
population = 10
iterations = 8
epochs_for_evaluation = 6
batch_size = 4096
early_stopping = 3


from mealpy.swarm_based import FA, GWO, PSO
from mealpy.utils.space import IntegerVar, FloatVar, BoolVar, CategoricalVar

# define objective
objective_function = torch_gpu_processing.set_ae_optimizer_objective(
    X_train_sample,
    y_train_sample,
    X_validation.to_numpy(), # Pass full validation, helper handles downsampling
    y_validation.to_numpy(),
    max_epochs=epochs_for_evaluation,
    batch_size=batch_size,
    seed=seed,
    early_stopping_patience=early_stopping
)

# 2. Define Bounds (AE Specific)
bounds_cfg = hyp_optimizer.get_ae_hyperparameter_bounds_config(min_layers=1, max_layers=4)
optimizer_bounds = []
for cfg in bounds_cfg:
    if cfg['type'] == 'int':
        optimizer_bounds.append(IntegerVar(lb=cfg['lb'], ub=cfg['ub'], name=cfg.get('name')))
    elif cfg['type'] == 'float':
        optimizer_bounds.append(FloatVar(lb=cfg['lb'], ub=cfg['ub'], name=cfg.get('name')))
    elif cfg['type'] == 'bool':
        optimizer_bounds.append(BoolVar(name=cfg.get('name')))
    elif cfg['type'] == 'categorical':
        optimizer_bounds.append(CategoricalVar(valid_sets=cfg['choices'], name=cfg.get('name')))

problem = dict(obj_func=objective_function, bounds=optimizer_bounds, minmax="min", log_to=None)

# 3. Run Optimizer
print(f"Starting AE Optimization using {param_optimizer_algorithm}...")
optimizer = FA.OriginalFA(epoch=iterations, pop_size=population)

best_agent = optimizer.solve(problem)
best_vec = best_agent.solution
best_obj = best_agent.target.fitness
best_hp = hyp_optimizer.optimizer_vectors_to_ae_hyperparams(best_vec)

print("\n=== BEST SOLUTION ===")
print(f"Best Objective (1-F1): {best_obj:.6f} => F1: {1-best_obj:.6f}")
print(f"Best Hyperparameters: {best_hp}")
# Out:
# Starting AE Optimization using FA...
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3215892553989894, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.3215892553989894, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.3215892553989894, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34664039074425707, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34664039074425707, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.34664039074425707, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.34664039074425707, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34664039074425707, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34664039074425707, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34421854935819873, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34421854935819873, inplace=False)
#   (8): Linear(in_features=16, out_features=4, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=4, out_features=24, bias=True)
#   (11): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): LeakyReLU(negative_slope=0.01)
#   (13): Dropout(p=0.34421854935819873, inplace=False)
#   (14): Linear(in_features=24, out_features=24, bias=True)
#   (15): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.34421854935819873, inplace=False)
#   (18): Linear(in_features=24, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.34421854935819873, inplace=False)
#   (22): Linear(in_features=16, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34421854935819873, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.022636907438517873, inplace=False)
#   (3): Linear(in_features=16, out_features=16, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.022636907438517873, inplace=False)
#   (6): Linear(in_features=16, out_features=24, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Dropout(p=0.022636907438517873, inplace=False)
#   (9): Linear(in_features=24, out_features=16, bias=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.022636907438517873, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): LeakyReLU(negative_slope=0.01)
#   (16): Dropout(p=0.022636907438517873, inplace=False)
#   (17): Linear(in_features=16, out_features=32, bias=True)
#   (18): LeakyReLU(negative_slope=0.01)
#   (19): Dropout(p=0.022636907438517873, inplace=False)
#   (20): Linear(in_features=32, out_features=16, bias=True)
#   (21): ReLU()
#   (22): Dropout(p=0.022636907438517873, inplace=False)
#   (23): Linear(in_features=16, out_features=32, bias=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.022636907438517873, inplace=False)
#   (26): Linear(in_features=32, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.25231959965459483, inplace=False)
#   (3): Linear(in_features=16, out_features=24, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.25231959965459483, inplace=False)
#   (6): Linear(in_features=24, out_features=16, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Dropout(p=0.25231959965459483, inplace=False)
#   (9): Linear(in_features=16, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=32, bias=True)
#   (12): LeakyReLU(negative_slope=0.01)
#   (13): Dropout(p=0.25231959965459483, inplace=False)
#   (14): Linear(in_features=32, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.451772506356171, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.451772506356171, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.451772506356171, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=24, bias=True)
#   (15): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.451772506356171, inplace=False)
#   (18): Linear(in_features=24, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.451772506356171, inplace=False)
#   (22): Linear(in_features=16, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU()
#   (25): Dropout(p=0.451772506356171, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=24, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.0002031164798890206, inplace=False)
#   (3): Linear(in_features=24, out_features=16, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.0002031164798890206, inplace=False)
#   (6): Linear(in_features=16, out_features=16, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Dropout(p=0.0002031164798890206, inplace=False)
#   (9): Linear(in_features=16, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=16, bias=True)
#   (12): ReLU()
#   (13): Dropout(p=0.0002031164798890206, inplace=False)
#   (14): Linear(in_features=16, out_features=16, bias=True)
#   (15): LeakyReLU(negative_slope=0.01)
#   (16): Dropout(p=0.0002031164798890206, inplace=False)
#   (17): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.40659216128566755, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.40659216128566755, inplace=False)
#   (8): Linear(in_features=16, out_features=32, bias=True)
#   (9): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.40659216128566755, inplace=False)
#   (12): Linear(in_features=32, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): LeakyReLU(negative_slope=0.01)
#   (15): Dropout(p=0.40659216128566755, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.40659216128566755, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU()
#   (25): Dropout(p=0.40659216128566755, inplace=False)
#   (26): Linear(in_features=16, out_features=16, bias=True)
#   (27): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU()
#   (29): Dropout(p=0.40659216128566755, inplace=False)
#   (30): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3215892553989894, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.3215892553989894, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.3215892553989894, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.32747105974379814, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.32747105974379814, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.32747105974379814, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.33646199621488815, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.33646199621488815, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.33646199621488815, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3215892553989894, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.3215892553989894, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.3215892553989894, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3215892553989894, inplace=False)
#   (4): Linear(in_features=16, out_features=4, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=4, out_features=24, bias=True)
#   (7): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): Dropout(p=0.3215892553989894, inplace=False)
#   (10): Linear(in_features=24, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.3215892553989894, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34752414823478445, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34752414823478445, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.34752414823478445, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.34752414823478445, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34752414823478445, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34752414823478445, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34664039074425707, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34664039074425707, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.34664039074425707, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.34664039074425707, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34664039074425707, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34664039074425707, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34664039074425707, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34664039074425707, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.34664039074425707, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.34664039074425707, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34664039074425707, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34664039074425707, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34429899021509686, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34429899021509686, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.34429899021509686, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.34429899021509686, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34429899021509686, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU()
#   (25): Dropout(p=0.34429899021509686, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.3317700470091373, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3317700470091373, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3317700470091373, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3317700470091373, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.3317700470091373, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU()
#   (25): Dropout(p=0.3317700470091373, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.34664039074425707, inplace=False)
#   (4): Linear(in_features=16, out_features=16, bias=True)
#   (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.34664039074425707, inplace=False)
#   (8): Linear(in_features=16, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): LeakyReLU(negative_slope=0.01)
#   (11): Dropout(p=0.34664039074425707, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.34664039074425707, inplace=False)
#   (18): Linear(in_features=16, out_features=32, bias=True)
#   (19): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.34664039074425707, inplace=False)
#   (22): Linear(in_features=32, out_features=16, bias=True)
#   (23): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): LeakyReLU(negative_slope=0.01)
#   (25): Dropout(p=0.34664039074425707, inplace=False)
#   (26): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.44274960758761595, inplace=False)
#   (3): Linear(in_features=16, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.44274960758761595, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=16, bias=True)
#   (6): ReLU()
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4458186448921415, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4458186448921415, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.4523819156916241, inplace=False)
#   (3): Linear(in_features=16, out_features=8, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=8, out_features=16, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.4523819156916241, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.4392640640533903, inplace=False)
#   (3): Linear(in_features=16, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=16, bias=True)
#   (6): ReLU()
#   (7): Dropout(p=0.4392640640533903, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.44524913631741037, inplace=False)
#   (3): Linear(in_features=16, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=16, bias=True)
#   (6): ReLU()
#   (7): Dropout(p=0.44524913631741037, inplace=False)
#   (8): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.3583917128046104, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3583917128046104, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3583917128046104, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3583917128046104, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.364368944038566, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.364368944038566, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.364368944038566, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.364368944038566, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.36865524140403544, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.36865524140403544, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.36865524140403544, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.36865524140403544, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3643121194081444, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3643121194081444, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3643121194081444, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3643121194081444, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.35959757225728717, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.35959757225728717, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.35959757225728717, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.35959757225728717, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.3619105875154784, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3619105875154784, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3619105875154784, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3619105875154784, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.36178187718614535, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.36178187718614535, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.36178187718614535, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.36178187718614535, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3663017939409059, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3663017939409059, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3663017939409059, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3663017939409059, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.36782665593840297, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.36782665593840297, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.36782665593840297, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.36782665593840297, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): LeakyReLU(negative_slope=0.01)
# ...
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.22194217348083098, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.22194217348083098, inplace=False)
#   (8): Linear(in_features=24, out_features=4, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=4, out_features=16, bias=True)
#   (11): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU()
#   (13): Dropout(p=0.22194217348083098, inplace=False)
#   (14): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.2163333673702864, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.2163333673702864, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.2163333673702864, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.2163333673702864, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.2163333673702864, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.2163333673702864, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.2163333673702864, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.2163333673702864, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.2163333673702864, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.2163333673702864, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.2163333673702864, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.2163333673702864, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.2163333673702864, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.2163333673702864, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.2163333673702864, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.2163333673702864, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Dropout(p=0.2163333673702864, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.2163333673702864, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.2163333673702864, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.2163333673702864, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.2163333673702864, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.2163333673702864, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.2163333673702864, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.2163333673702864, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.2163333673702864, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.36587507928445734, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.36587507928445734, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.36587507928445734, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.36587507928445734, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.36461618893633824, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.36461618893633824, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.36461618893633824, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.36461618893633824, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.3632023842212617, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.3632023842212617, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.3632023842212617, inplace=False)
#   (12): Linear(in_features=16, out_features=4, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=4, out_features=16, bias=True)
#   (15): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU()
#   (17): Dropout(p=0.3632023842212617, inplace=False)
#   (18): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.4271294502809525, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.4271294502809525, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.4271294502809525, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.4271294502809525, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.4271294502809525, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.42109197758626565, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.42109197758626565, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.42109197758626565, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.42109197758626565, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Dropout(p=0.42109197758626565, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ......]
# Sequential(
#   (0): Linear(in_features=26, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Dropout(p=0.43120486473622205, inplace=False)
#   (4): Linear(in_features=16, out_features=24, bias=True)
#   (5): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.43120486473622205, inplace=False)
#   (8): Linear(in_features=24, out_features=16, bias=True)
#   (9): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Dropout(p=0.43120486473622205, inplace=False)
#   (12): Linear(in_features=16, out_features=24, bias=True)
#   (13): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU()
#   (15): Dropout(p=0.43120486473622205, inplace=False)
#   (16): Linear(in_features=24, out_features=4, bias=True)
#   (17): ReLU()
#   (18): Linear(in_features=4, out_features=16, bias=True)
#   (19): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): LeakyReLU(negative_slope=0.01)
#   (21): Dropout(p=0.43120486473622205, inplace=False)
#   (22): Linear(in_features=16, out_features=26, bias=True)
# )
# ....

# %%
# ==========================================
# FINAL MODEL TRAINING
# ==========================================

model, metrics = torch_gpu_processing.train_final_ae_model(
    best_hp,
    X_train.to_numpy(),
    y_train.to_numpy(),
    X_test.to_numpy(),
    y_test.to_numpy(),
    batch_size=batch_size,
    max_epochs=50
)

print("Final Evaluation (Test Set):", metrics)
